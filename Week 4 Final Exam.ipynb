# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# <b> Felix Daubner <b>

# %% [markdown]
# <i> I am interested in data science because I like analytical thinking and programming. Extracting knowledge out of data to gain value for your organization is something I want to pursue in my career. <i>

# %% [markdown]
# <h3> My code prints out the average of all numbers included in the Python list. <h3>

# %%
mylist = [1,4,6,4,3,6,9,8,4]

result = 0

for num in mylist:
    result = result + num
    
print("The average is {}".format(result / len(mylist)))
# Out:
# The average is 5.0

# %% [markdown]
# - this
# - is
# - a
# - bulleted
# - list
#
# 1. this
# 2. is
# 3. a
# 4. numbered
# 5. list
#
# |heading|heading|
# |----|----|
# |text|text|
# |text|text|
